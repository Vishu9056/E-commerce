# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-35-b478a6fd18e5> in <module>()
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#
# /home/vishwajeet/.local/lib/python2.7/site-packages/matplotlib/__init__.py in <module>()
#     127 # cbook must import matplotlib only within function
#     128 # definitions, so it is safe to import from it here.
# --> 129 from . import cbook
#     130 from matplotlib.cbook import (
#     131     _backports, mplDeprecation, dedent, get_label, sanitize_sequence)
#
# ImportError: cannot import name cbook

# %%
data=pd.read_csv('president_county.csv')

# %%
# Out:
#                      state                county  current_votes  total_votes  \
# 0                 Delaware           Kent County          86958        88000
# 1                 Delaware     New Castle County         286133       293878
# 2                 Delaware         Sussex County         129293       125000
# 3     District of Columbia  District of Columbia          31260        45392
# 4     District of Columbia                Ward 2          27259        37140
# 5     District of Columbia                Ward 3          37377        47692
# 6     District of Columbia                Ward 4          37223        45917
# 7     District of Columbia                Ward 5          38778        44719
# 8     District of Columbia                Ward 6          49394        57889
# 9     District of Columbia                Ward 7          31823        37287
# 10    District of Columbia                Ward 8          26038        32583
# ...

# %%
# %matplotlib inline
plt.xlabel('current_votes')
plt.ylabel('total_votes')
plt.scatter(data.current_votes,data.total_votes,color='red',marker='+')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-37-52a8fa913165> in <module>()
# ----> 1 get_ipython().magic(u'matplotlib inline')
#       2 plt.xlabel('current_votes')
#       3 plt.ylabel('total_votes')
#       4 plt.scatter(data.current_votes,data.total_votes,color='red',marker='+')
#
# /home/vishwajeet/.local/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2158         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2159         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2160         return self.run_line_magic(magic_name, magic_arg_s)
#    2161
#    2162     #-------------------------------------------------------------------------
#
# /home/vishwajeet/.local/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
# ...

# %%
new_data=data.drop('state',axis='columns')
new_data
# Out:
#                     county  current_votes  total_votes  percent
# 0              Kent County          86958        88000       95
# 1        New Castle County         286133       293878       95
# 2            Sussex County         129293       125000       95
# 3     District of Columbia          31260        45392       69
# 4                   Ward 2          27259        37140       73
# 5                   Ward 3          37377        47692       78
# 6                   Ward 4          37223        45917       81
# 7                   Ward 5          38778        44719       87
# 8                   Ward 6          49394        57889       85
# 9                   Ward 7          31823        37287       85
# 10                  Ward 8          26038        32583       80
# 11          Alachua County         142784       142784       99
# 12            Baker County          14082        14059       99
# 13              Bay County          93131       106100       88
# ...
